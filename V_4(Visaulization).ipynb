# %%
import re
import nltk

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
english_stemmer=nltk.stem.SnowballStemmer('english')

from sklearn.feature_selection.univariate_selection import SelectKBest, chi2, f_classif
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier, SGDRegressor
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import random
import itertools

import sys
import os
import argparse
from sklearn.pipeline import Pipeline
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import CountVectorizer
import six
from abc import ABCMeta
from scipy import sparse
from scipy.sparse import issparse
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils import check_X_y, check_array
from sklearn.utils.extmath import safe_sparse_dot
from sklearn.preprocessing import normalize, binarize, LabelBinarizer
from sklearn.svm import LinearSVC

from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Lambda
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM, SimpleRNN, GRU
from keras.preprocessing.text import Tokenizer
from collections import defaultdict
from keras.layers.convolutional import Convolution1D
from keras import backend as K

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline
plt.style.use('ggplot')

# %%
data_file = './Child(preprocessing).csv'
n = 122676  
s = 122676
skip = sorted(random.sample(range(1,n),n-s))


df = pd.read_csv( data_file, delimiter = ",", skiprows = skip, encoding = 'cp949')
#41만개의 데이터 중 3000개의 데이터만 뽑아서 분석을 진행
# Out:
# /Users/Moon/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (24,25,28,29,30,32,33,34,35,36,40,43,49,53,54,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.isnull().sum()
# Out:
# 개별사건번호              0
# 피해아동 대상자ID          0
# 학대행위자 대상자ID         0
# 성별                306
# 생년월일            15674
#                 ...
# 아동 관계 구분코드     120247
# 아동 동거 여부.1       1138
# 특별관리유형         116903
# 학대 혐의 여부            0
# 학대 유형           76780
# Length: 77, dtype: int64

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#이거 꼭 기억하기 개꿀따리임

# %%
df.tail()
# Out:
#                         개별사건번호         피해아동 대상자ID        학대행위자 대상자ID 성별  \
# 122671  1201120120140100010001  CASRCP20130310175  CASRCP20140220184  F
# 122672  1001100120140100010001  CASRCP20140110966  CASRCP20140121028  M
# 122673  1001100120140100020001  CASRCP20140110878  CASRCP20140121028  F
# 122674  1502150220140100020001  CASRCP20110610831  CASRCP20110620594  M
# 122675  1502150220140100010001  CASRCP20110610830  CASRCP20110620594  F
#
#               생년월일 내국인여부  교육기관 최종 학력 직업 유형 거주상태 친권자 유형     가족 유형 다문화가족  \
# 122671         NaN   내국인   NaN  고등중퇴  고등학교  NaN     친모        기타    일반
# 122672  19960506.0   내국인   NaN   NaN   NaN   자택     친모  모자가족(이혼)    일반
# 122673  19990623.0   내국인   NaN   NaN   NaN   자택     친모  모자가족(이혼)    일반
# 122674  20021029.0   내국인   NaN   NaN   NaN   전세     친부  부자가족(이혼)    일반
# 122675  19990921.0   내국인   NaN   NaN   NaN  NaN    NaN  부자가족(별거)    일반
#
#              가구 소득 구분코드 기초생활수급 유형    접수 경로 구분코드        접수 일시 신고자 유형 구분코드  \
# ...

# %%
df.isnull().sum()
#교육기관, 최종학력, 직업유형, 거주상태, 가구 소득 구분 코드, 기초생활 수급 유형, 통보 경찰 소속 기관, 일반상담 유형, 동일신고 여부, 동일신고 관리 기관, 동일신고이전접수, 오인신고 유형, 오인시고 사유, 특별 관리 유형, 관할지구대, 오인신고확인기관, 행위자수탁명령 ,행위자수탁명령결정, 피해아동 상태 구분, 재신고센터ID, 동일신고관리, 재신고유형.1, 재신고센터ID.1, 재신고유형기타, 이전신고여부, 동일신고이전, 재신고이전, 집단 시설내사건, 재신고 유형 구분코드, 재신고 관리 기관, 재신고 이전 사건, 동일신고 이전 사건, 보호자 학대 여부, 아동 관계 구분코드, 특별관리유형, 학대유형
# Out:
# 개별사건번호              0
# 피해아동 대상자ID          0
# 학대행위자 대상자ID         0
# 성별                306
# 생년월일            15674
# 내국인여부           16292
# 교육기관           122676
# 최종 학력           75520
# 직업 유형           77099
# 거주상태            62605
# 친권자 유형           9489
# 가족 유형           10000
# 다문화가족           21040
# 가구 소득 구분코드      73118
# 기초생활수급 유형       43621
# 접수 경로 구분코드          0
# 접수 일시               0
# 신고자 유형 구분코드         0
# 신고자유형기타내용       51473
# 통보 경찰 소속 기관     66993
# 통보 일시           35507
# 접수 부가확인사항       58320
# 집단 시설내사건 구분     58320
# 재신고 여부(17년)     40241
# 재신고 유형         112516
# 재신고 유형 기타      122525
# 재신고이전접수번호      112532
# 접수 유형               0
# 일반상담 유형        122675
# 동일신고 여부        122675
# 동일신고 관리 기관     122667
# 동일신고이전접수       122671
# 오인신고 유형        122669
# 오인신고 사유        122645
# 특별 관리 유형       122433
# 관할지구대           97957
# 오인신고확인기관       122652
# 신고접수 구분             0
# 접수자소속기관명            0
# 관할 지역 ID          341
# 행위자수탁명령        122609
# ...

# %%
df1 = df.drop(['교육기관', '최종 학력', '직업 유형', '거주상태', '가구 소득 구분코드', '기초생활수급 유형', '통보 경찰 소속 기관', '일반상담 유형', '동일신고 여부','동일신고 관리 기관', '동일신고이전접수', '오인신고 유형', '오인신고 사유', '특별 관리 유형', '관할지구대', '오인신고확인기관', '행위자수탁명령' ,'행위자수탁명령결정', '피해아동 상태 구분', '재신고센터ID', '동일신고관리', '재신고 유형.1', '재신고센터ID.1', '재신고유형기타', '이전신고여부', '동일신고이전', '재신고이전', '집단 시설내사건', '재신고 유형 구분코드', '재신고 관리 기관', '재신고 이전 사건', '동일신고 이전 사건', '보호자 학대 여부', '아동 관계 구분코드', '특별관리유형', '학대 유형'], axis = 1)
#결측치가 50%를 넘어가는 column을 삭제

# %%
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df.isnull().sum()
#이렇게 50%가 넘는 컬럼을 제거하고 결측치를 제거하면 최종적으로 8개의 Row만 남음
# Out:
# 개별사건번호              0
# 피해아동 대상자ID          0
# 학대행위자 대상자ID         0
# 성별                306
# 생년월일            15674
# 내국인여부           16292
# 교육기관           122676
# 최종 학력           75520
# 직업 유형           77099
# 거주상태            62605
# 친권자 유형           9489
# 가족 유형           10000
# 다문화가족           21040
# 가구 소득 구분코드      73118
# 기초생활수급 유형       43621
# 접수 경로 구분코드          0
# 접수 일시               0
# 신고자 유형 구분코드         0
# 신고자유형기타내용       51473
# 통보 경찰 소속 기관     66993
# 통보 일시           35507
# 접수 부가확인사항       58320
# 집단 시설내사건 구분     58320
# 재신고 여부(17년)     40241
# 재신고 유형         112516
# 재신고 유형 기타      122525
# 재신고이전접수번호      112532
# 접수 유형               0
# 일반상담 유형        122675
# 동일신고 여부        122675
# 동일신고 관리 기관     122667
# 동일신고이전접수       122671
# 오인신고 유형        122669
# 오인신고 사유        122645
# 특별 관리 유형       122433
# 관할지구대           97957
# 오인신고확인기관       122652
# 신고접수 구분             0
# 접수자소속기관명            0
# 관할 지역 ID          341
# 행위자수탁명령        122609
# ...

# %%
for i in df.columns:
    print(i ,':', df[i].unique())
# Out:
# 개별사건번호 : ['5722572220181200160001' '6603660320181200090001'
#  '6002600220181200040001' ... '1001100120140100020001'
#  '1502150220140100020001' '1502150220140100010001']
# 피해아동 대상자ID : ['CASRCP20190100282' 'CASRCP20190101182' 'CASRCP20190100497' ...
#  'CASRCP20140110878' 'CASRCP20110610831' 'CASRCP20110610830']
# 학대행위자 대상자ID : ['CASRCP20190100283' 'CASRCP20190101183' 'CASRCP20190100498' ...
#  'CASRCP20140220184' 'CASRCP20140121028' 'CASRCP20110620594']
# 성별 : ['M' 'F' 'Z' nan]
# 생년월일 : [20051005. 20041107. 20040218. ... 19960203. 19970127. 19960506.]
# 내국인여부 : ['내국인' nan '외국인' '무국적']
# 교육기관 : [nan]
# 최종 학력 : ['재학중' nan '무학' '중등졸업' '고등중퇴' '초등졸업' '중등중퇴' '고등졸업' '초등중퇴' '대학원이상' '대학졸업'
#  '대학중퇴']
# 직업 유형 : ['중학교' nan '고등학교' '초등학교' '유치원' '어린이집' '무직' '기타' '기술공 및 준전문가' '전문가' '사무종사자'
#  '서비스 및 판매종사자' '관리자' '군인' '단순노무종사자' '장치·기계조작 및 조립 종사자' '농림어업숙련종사자'
#  '기능원 및 관련 기능 종사자']
# 거주상태 : ['자택' nan '월세' '기타' '전세' '보증금(전세)+월세' '보호시설' '영구임대아파트  또는 영구임대주택' '무상']
# ...

# %%
df['학대 유형'].value_counts().plot(kind='bar')
print(df['학대 유형'].value_counts())
# Out:
# 이혼 및 양육권 소송상담      17895
# 양육관련상담             12843
# 성인이 아닌 자에 의한 학대    12275
# 시설입소상담              2883
# Name: 학대 유형, dtype: int64

# %%
df['학대 혐의 여부'].value_counts().plot(kind='bar')
print(df['학대 혐의 여부'].value_counts())
# Out:
# Y    87960
# N    34716
# Name: 학대 혐의 여부, dtype: int64

# %%
df['재신고 여부.1'].value_counts().plot(kind='bar')
print(df['재신고 여부.1'].value_counts())
# Out:
# N    107000
# Y     15676
# Name: 재신고 여부.1, dtype: int64

# %%
df['조사 완료 여부'].value_counts().plot(kind='bar')
print(df['조사 완료 여부'].value_counts())
# Out:
# Y    120082
# N      2594
# Name: 조사 완료 여부, dtype: int64

# %%
df['이전신고여부'].value_counts().plot(kind='bar')
print(df['이전신고여부'].value_counts())
# Out:
# N    702
# Name: 이전신고여부, dtype: int64

# %%
df[['재신고 여부'] == 'Y' and ['재신고센터ID.1']]
#찾아보기
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-ecaf4413119f> in <module>
# ...

# %%
df['아동 동거 여부'].value_counts().plot(kind='bar')
print(df['아동 동거 여부'].value_counts())
# Out:
# 동거     86472
# 비동거    31316
# Name: 아동 동거 여부, dtype: int64

# %%
df['행위자 아동 관계'].value_counts().plot(kind='bar')
print(df['행위자 아동 관계'].value_counts())
# Out:
# 친부                            48431
# 친모                            35937
# 어린이집(보육교직원, 종사자)               7397
# 학교(교원, 교직원)                    6158
# 아동복지시설종사자                      3008
# 유치원(교사,교직원, 종사자)               2361
# 기타                             2348
# 계부                             2042
# 친인척                            1985
# 계모                             1871
# 친조모                            1417
# 학원(강사, 종사자)                    1143
# 부모의 동거인                        1024
# 형제자매                            925
# 낯선사람                            895
# 친조부                             842
# 외조모                             673
# 이웃                              651
# 기타시설종사자                         386
# 외조부                             331
# 양부                              162
# 양모                              128
# 청소년관련시설종사자                      116
# 베이비시터(아이돌보미)                    105
# 위탁모                              60
# 위탁부                              28
# ...

# %%
from collections import Counter
for i in df['재신고센터ID'].isnull():
    if i == True:
        Counter(i)
        
#재신고센터ID와 관할지역기관ID가 같은건지 확인해보기
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-1e4c37087eba> in <module>
#       2 for i in df['재신고센터ID'].isnull():
#       3     if i == True:
# ----> 4         Counter(i)
#
# ~/opt/anaconda3/lib/python3.7/collections/__init__.py in __init__(*args, **kwds)
#     566             raise TypeError('expected at most 1 arguments, got %d' % len(args))
#     567         super(Counter, self).__init__()
# --> 568         self.update(*args, **kwds)
#     569
#     570     def __missing__(self, key):
#
# ~/opt/anaconda3/lib/python3.7/collections/__init__.py in update(*args, **kwds)
#     653                     super(Counter, self).update(iterable) # fast path when counter is empty
#     654             else:
# --> 655                 _count_elements(self, iterable)
#     656         if kwds:
#     657             self.update(kwds)
#
# ...

# %%
df['피해아동 상태 구분'].value_counts().plot(kind='bar')
print(df['피해아동 상태 구분'].value_counts())
# Out:
# 해당사항없음          39530
# 아동사망               35
# 중상해(의식불명 포함)       17
# Name: 피해아동 상태 구분, dtype: int64

# %%
df['관할 지역 ID'].value_counts().plot(kind='bar')
print(df['관할 지역 ID'].value_counts())
# Out:
# 서구         4186
# 북구         3912
# 남구         3630
# 단원구        2464
# 동구         2278
# 상록구        2258
# 중구         2202
# 목포시        1585
# 제주시        1563
# 익산시        1517
# 남양주시       1496
# 달서구        1485
# 구미시        1396
# 화성시        1356
# 완산구        1337
# 남동구        1313
# 의정부시       1292
# 미추홀구       1255
# 부평구        1254
# 원주시        1250
# 시흥시        1228
# 군산시        1192
# 평택시        1133
# 강서구        1116
# 김해시        1115
# 은평구        1083
# 덕진구        1045
# 남원시         992
# 서귀포시        964
# 부산진구        962
# 서북구         927
# 해운대구        922
# 안동시         916
# 춘천시         895
# 노원구         887
# 광산구         876
# 진주시         870
# 순천시         857
# 계양구         846
# 도봉구         834
# 여수시         818
# 양천구         807
# 중랑구         806
# 권선구         806
# 충주시         786
# 연수구         765
# 수정구         760
# 강릉시         759
# 아산시         752
# 구로구         751
# 제천시         744
# 광명시         742
# 성북구         727
# 원미구         726
# 흥덕구         725
# ...

# %%
df['접수자소속기관명'].value_counts().plot(kind='bar')
print(df['접수자소속기관명'].value_counts())
# Out:
# 안산                 2161
# 경남                 1965
# 울산                 1927
# 전북서부               1773
# 전북                 1746
# 서울동부               1669
# 경기                 1627
# 경기성남               1559
# 안산시아동보호전문기관        1539
# 경기북부               1513
# 충북                 1500
# 인천                 1494
# 충남                 1423
# 경기화성               1378
# 부산광역시아동보호전문기관      1360
# 경북동부               1342
# 대전                 1281
# 경기용인               1280
# 부산동부               1267
# 전라북도서부아동보호전문기관     1240
# 전라북도아동보호전문기관       1209
# 전남                 1206
# 전남서부권              1168
# 경기부천               1153
# 경북동부아동보호전문기관       1119
# 수원아동보호전문기관         1093
# 전남서부권아동보호전문기관      1088
# 경기고양               1082
# 전라남도아동보호전문기관       1080
# 광주                 1063
# 전남중부권              1050
# 경기북부아동보호전문기관       1038
# 서울                 1025
# 경상남도아동보호전문기관       1021
# 서울영등포              1018
# 경북서부아동보호전문기관       1016
# 부산                 1015
# 인천북부아동보호전문기관        992
# ...

# %%
df['신고접수 구분'].value_counts().plot(kind='bar')
print(df['신고접수 구분'].value_counts())
# Out:
# 아동보호전문기관접수    84382
# 경찰접수          38294
# Name: 신고접수 구분, dtype: int64

# %%
df['특별 관리 유형'].value_counts().plot(kind='bar')
print(df['특별 관리 유형'].value_counts())
# Out:
# 공동모금회사업          242
# 가족재결합 평가도구 사용      1
# Name: 특별 관리 유형, dtype: int64

# %%
df['동일신고 여부'].value_counts().plot(kind='bar')
print(df['동일신고 여부'].value_counts())
# Out:
# Y    1
# Name: 동일신고 여부, dtype: int64

# %%
df['접수 유형'].value_counts().plot(kind='bar')
print(df['접수 유형'].value_counts())
# Out:
# 아동학대 의심사례                        122601
# 학대행위자 법원명령을 통한 인지(임시조치, 보호처분)        73
# 피해아동보호명령을 통한 인지                       1
# 일반상담                                  1
# Name: 접수 유형, dtype: int64

# %%
df['재신고 여부(17년)'].value_counts().plot(kind='bar')
print(df['재신고 여부(17년)'].value_counts())
# Out:
# 없음    72276
# 있음    10159
# Name: 재신고 여부(17년), dtype: int64

# %%
df['집단 시설내사건 구분'].value_counts().plot(kind='bar')
print(df['집단 시설내사건 구분'].value_counts())
# Out:
# 해당사항없음    59206
# 교육기관       2798
# 어린이집       1297
# 시설          882
# 기타          173
# Name: 집단 시설내사건 구분, dtype: int64

# %%
df['접수 부가확인사항'].value_counts().plot(kind='bar')
print(df['접수 부가확인사항'].value_counts())
# Out:
# 해당사항없음    63479
# 언론노출        877
# Name: 접수 부가확인사항, dtype: int64

# %%
df['신고자 유형 구분코드'].value_counts().plot(kind='bar')
print(df['신고자 유형 구분코드'].value_counts())
# Out:
# 부모                                21228
# 교직원, 전문상담교사, 산학겸임교사               19819
# 아동보호전문기관장과종사자                     15415
# 아동본인                              12912
# 사회복지관련종사자                         11783
# 이웃,친구                              7952
# 경찰                                 5531
# 사회복지전담공무원                          3604
# 기타                                 3471
# 친인척                                3006
# 낯선사람                               2294
# 아동복지시설종사자                          1859
# 형제,자매                              1455
# 보육교직원                              1399
# 취약계층아동 통합서비스 지원인력                  1233
# 가정폭력상담소보호시설종사자                     1225
# 청소년시설,단체종사자                        1188
# 사회복지시설종사자                          1162
# 의료인, 의료기사                          1109
# 익명                                  974
# 아동보호전문기관상담원                         685
# 성폭력피해자통합지원센터종사자, 성폭력피해자보호시설종사자      456
# 유치원교직원,강사                           453
# ...

# %%
df['최종 학력'].value_counts().plot(kind='bar')
print(df['최종 학력'].value_counts())
# Out:
# 재학중      43022
# 무학        2425
# 고등중퇴       616
# 중등졸업       371
# 초등졸업       360
# 중등중퇴       174
# 고등졸업       115
# 대학원이상       33
# 초등중퇴        32
# 대학졸업         7
# 대학중퇴         1
# Name: 최종 학력, dtype: int64

# %%
df['내국인여부'].value_counts().plot(kind='bar')
print(df['내국인여부'].value_counts())
# Out:
# 내국인    105693
# 외국인       685
# 무국적         6
# Name: 내국인여부, dtype: int64

# %% [markdown]
# ### EDA

# %%
df['거주상태'].value_counts().plot(kind='bar')
print(df['거주상태'].value_counts())
# Out:
# 자택                    5679
# 보증금(전세)+월세            2750
# 전세                    1901
# 월세                    1430
# 영구임대아파트  또는 영구임대주택    1083
# 기타                     693
# 보호시설                   634
# 무상                     416
# Name: 거주상태, dtype: int64

# %%
df['가구 소득 구분코드'].value_counts().plot(kind='bar')
print(df['가구 소득 구분코드'].value_counts())
# Out:
# 300만원이상            3380
# 100만원이상-150만원미만    1816
# 150만원이상-200만원미만    1799
# 200만원이상-250만원미만    1664
# 50만원이상~100만원미만     1254
# 250만원이상-300만원미만    1156
# 50만원미만             1056
# Name: 가구 소득 구분코드, dtype: int64

# %%
df['기초생활수급 유형'].value_counts().plot(kind='bar')
print(df['기초생활수급 유형'].value_counts())
#오호?(지정한 가정이 잘못되었음 )
# Out:
# 비수급권대상    15092
# 수급권대상      4242
# Name: 기초생활수급 유형, dtype: int64

# %%
df['가족 유형'].value_counts().plot(kind='bar')
print(df['가족 유형'].value_counts())
# Out:
# 친부모가정        15521
# 부자가족(이혼)      2905
# 모자가족(이혼)      2519
# 재혼가정          1723
# 동거(사실혼포함)      738
# 친인척보호          645
# 모자가족(별거)       632
# 시설보호           537
# 미혼부·모가정        479
# 부자가족(별거)       442
# 모자가족(사별)       392
# 부자가족(가출)       347
# 부자가족(사별)       219
# 기타             147
# 모자가족(가출)        99
# 입양가정            95
# 위탁가정            44
# 소년소녀가정          15
# Name: 가족 유형, dtype: int64

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 10.0
mosaic(df, ['학대 혐의 여부', '가족 유형']);

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 10.0
mosaic(df, ['학대 혐의 여부', '기초생활수급 유형']);

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 10.0
mosaic(df, ['학대 혐의 여부', '가구 소득 구분코드']);

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 10.0
mosaic(df, ['가구 소득 구분코드', '기초생활수급 유형']);

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 10.0
mosaic(df, ['아동 동거 여부', '성별']);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-191-4751236e3898> in <module>
#       1 from statsmodels.graphics.mosaicplot import mosaic
#       2 plt.rcParams['font.size'] = 10.0
# ----> 3 mosaic(df, ['아동 동거 여부', '성별']);
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/graphics/mosaicplot.py in mosaic(data, index, ax, horizontal, gap, properties, labelizer, title, statistic, axes_label, label_rotation)
#     627     fig, ax = utils.create_mpl_ax(ax)
#     628     # normalize the data to a dict with tuple of strings as keys
# --> 629     data = _normalize_data(data, index)
#     630     # split the graph into different areas
#     631     rects = _hierarchical_split(data, horizontal=horizontal, gap=gap)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/graphics/mosaicplot.py in _normalize_data(data, index)
#     287     # pandas explicitly
# ...

# %%
mosaic(df.sort_values('거주상태'), ['거주상태'], gap=0.02 )

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-192-52c9e0cc4655> in <module>
# ----> 1 mosaic(df.sort_values('거주상태'), ['거주상태'], gap=0.02 )
#       2
#       3 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: '거주상태'

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 10.0
mosaic(df, ['거주상태', '친권자 유형']);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-193-17ae67eb6a47> in <module>
#       1 from statsmodels.graphics.mosaicplot import mosaic
#       2 plt.rcParams['font.size'] = 10.0
# ----> 3 mosaic(df, ['거주상태', '친권자 유형']);
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/graphics/mosaicplot.py in mosaic(data, index, ax, horizontal, gap, properties, labelizer, title, statistic, axes_label, label_rotation)
#     627     fig, ax = utils.create_mpl_ax(ax)
#     628     # normalize the data to a dict with tuple of strings as keys
# --> 629     data = _normalize_data(data, index)
#     630     # split the graph into different areas
#     631     rects = _hierarchical_split(data, horizontal=horizontal, gap=gap)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/graphics/mosaicplot.py in _normalize_data(data, index)
#     287     # pandas explicitly
# ...

# %%
plt.rcParams['font.size'] = 10.0
mosaic(df, ['친권자 유형', '가구 소득 구분코드']);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-194-d16339dc76ba> in <module>
#       1 plt.rcParams['font.size'] = 10.0
# ----> 2 mosaic(df, ['친권자 유형', '가구 소득 구분코드']);
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/graphics/mosaicplot.py in mosaic(data, index, ax, horizontal, gap, properties, labelizer, title, statistic, axes_label, label_rotation)
#     627     fig, ax = utils.create_mpl_ax(ax)
#     628     # normalize the data to a dict with tuple of strings as keys
# --> 629     data = _normalize_data(data, index)
#     630     # split the graph into different areas
#     631     rects = _hierarchical_split(data, horizontal=horizontal, gap=gap)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/graphics/mosaicplot.py in _normalize_data(data, index)
#     287     # pandas explicitly
# ...

# %%
a = df[['재신고 이전 사건','통계 거점']]
b = a['재신고 이전 사건'].notnull()
c= b.astype('int64')
#값이 존재하는 값은 1 아니면 0 
d = pd.concat([c,df['통계 거점']],axis = 1)
#붙임

# %%
e = d[d['재신고 이전 사건'] == 1]
print(e)
# Out:
#       재신고 이전 사건 통계 거점
# 0             1    강원
# 1             1    강원
# 2             1    경남
# 3             1    경북
# 4             1    제주
# 5             1    전북
# 6             1    강원
# 7             1    전북
# 8             1    경기
# 9             1    경북
# 10            1    전북
# 11            1    경북
# 12            1    부산
# 13            1    부산
# 14            1    전북
# 15            1    경남
# 16            1    경기
# 17            1    전북
# 18            1    경북
# 19            1    경북
# 20            1    강원
# 21            1    서울
# 22            1    서울
# 23            1    전북
# 24            1    강원
# 25            1    강원
# 26            1    부산
# 27            1    충북
# 28            1    경기
# 29            1    서울
# 30            1    경기
# 31            1    서울
# 32            1    충북
# 33            1    경북
# 34            1    경기
# 35            1    인천
# 36            1    경기
# 37            1    강원
# 38            1    대구
# 39            1    경북
# ...

# %%
df['통계 거점'].value_counts()
# Out:
# 경기    850
# 전북    434
# 서울    388
# 경북    317
# 강원    243
# 인천    215
# 전남    207
# 충북    193
# 충남    169
# 대구    151
# 울산    110
# 부산    103
# 경남    101
# 광주     84
# 대전     83
# 제주     79
# 세종      4
# 중앙      4
# Name: 통계 거점, dtype: int64

# %%
e['통계 거점'].value_counts().plot(kind='bar')
print(e['통계 거점'].value_counts())
# Out:
# 경기    850
# 전북    434
# 서울    388
# 경북    317
# 강원    243
# 인천    215
# 전남    207
# 충북    193
# 충남    169
# 대구    151
# 울산    110
# 부산    103
# 경남    101
# 광주     84
# 대전     83
# 제주     79
# 세종      4
# 중앙      4
# Name: 통계 거점, dtype: int64

# %%
f = []
for i in e['통계 거점']:
    if i == '경기':
        e['위도'] = 37.275230
        e['경도'] = 127.009477
    elif i == '전북':
        e['위도'] = 35.821859
        e['경도'] = 127.108598
    elif i == '서울':
        e['위도'] = 37.567996
        e['경도'] = 126.978166
    elif i == '경북':
        e['위도'] = 36.575889
        e['경도'] = 128.505793
    elif i == '인천':
        e['위도'] = 37.456390
        e['경도'] = 126.705971
    elif i == '강원':
        e['위도'] = 37.885523
        e['경도'] = 127.729760
    elif i == '전남':
        e['위도'] = 34.816295
        e['경도'] = 126.462874
    elif i == '충북':
        e['위도'] = 36.636007
        e['경도'] = 127.491345
    elif i == '충남':
        e['위도'] = 36.659435
        e['경도'] = 126.672866
    elif i == '대구':
        e['위도'] = 35.871613
        e['경도'] = 128.601836
    elif i == '울산':
        e['위도'] = 35.539171
        e['경도'] = 129.311425
    elif i == '부산':
        e['위도'] = 35.179872
        e['경도'] = 129.074988
    elif i == '경남':
        e['위도'] = 35.238168
        e['경도'] = 128.692397
    elif i == '광주':
        e['위도'] = 35.159823
        e['경도'] = 126.850831
    elif i == '대전':
        e['위도'] = 36.350491
        e['경도'] = 127.384593
    elif i == '제주':
        e['위도'] = 33.499677
        e['경도'] = 126.531247
    elif i == '세종':
        e['위도'] = 36.480263
        e['경도'] = 127.288977
    else:
        e['위도'] = 37.567996
        e['경도'] = 126.978166

#중앙을 잘모르기때문에 서울의 위경도를 사용

# %%
f = []
g = []
z = []
for i in e['통계 거점']:
    if i == '경기':
        z.append('경기')
        f.append(37.275230)
        g.append(127.009477)
    elif i == '전북':
        z.append('전북')
        f.append(35.821859)
        g.append(127.108598)
    elif i == '서울':
        z.append('서울')
        f.append(37.567996)
        g.append(126.978166)
    elif i == '경북':
        z.append('경북')
        f.append(36.575889)
        g.append(128.505793)
    elif i == '인천':
        z.append('인천')
        f.append(37.456390)
        g.append(126.705971)
    elif i == '강원':
        z.append('강원')
        f.append(37.885523)
        g.append(127.729760)
    elif i == '전남':
        z.append('전남')
        f.append(34.816295)
        g.append(126.462874)
    elif i == '충북':
        z.append('충북')
        f.append(36.636007)
        g.append(127.491345)
    elif i == '충남':
        z.append('충남')
        f.append(36.659435)
        g.append(126.672866)
    elif i == '대구':
        z.append('대구')
        f.append(35.871613)
        g.append(128.601836)
    elif i == '울산':
        z.append('울산')
        f.append(35.539171)
        g.append(129.311425)
    elif i == '부산':
        z.append('부산')
        f.append(35.179872)
        g.append(129.074988)
    elif i == '경남':
        z.append('경남')
        f.append(35.238168)
        g.append(128.692397)
    elif i == '광주':
        z.append('광주')
        f.append(35.159823)
        g.append(126.850831)
    elif i == '대전':
        z.append('대전')
        f.append(36.350491)
        g.append(127.384593)
    elif i == '제주':
        z.append('제주')
        f.append(33.499677)
        g.append(126.531247)
    elif i == '세종':
        z.append('세종')
        f.append(36.480263)
        g.append(127.288977)
    else:
        z.append('서울')
        f.append(37.567996)
        g.append(126.978166)

#중앙을 잘모르기때문에 서울의 위경도를 사용

# %%
f
# Out:
# [37.885523,
#  37.885523,
#  35.238168,
#  36.575889,
#  33.499677,
#  35.821859,
#  37.885523,
#  35.821859,
#  37.27523,
#  36.575889,
#  35.821859,
#  36.575889,
#  35.179872,
#  35.179872,
#  35.821859,
#  35.238168,
#  37.27523,
#  35.821859,
#  36.575889,
#  36.575889,
#  37.885523,
#  37.567996,
#  37.567996,
#  35.821859,
#  37.885523,
#  37.885523,
#  35.179872,
#  36.636007,
#  37.27523,
#  37.567996,
#  37.27523,
#  37.567996,
#  36.636007,
#  36.575889,
#  37.27523,
#  37.45639,
#  37.27523,
#  37.885523,
#  35.871613,
#  36.575889,
#  35.821859,
#  37.885523,
#  36.575889,
#  36.575889,
#  37.567996,
#  37.885523,
#  36.659435,
#  35.159823,
#  37.27523,
#  37.567996,
#  36.659435,
#  36.350491,
#  37.27523,
#  35.539171,
#  37.567996,
#  35.159823,
#  37.27523,
#  34.816295,
#  34.816295,
#  37.27523,
#  37.567996,
#  37.27523,
#  35.821859,
#  37.27523,
#  37.885523,
#  37.27523,
#  37.27523,
#  35.821859,
#  33.499677,
#  37.45639,
#  37.567996,
#  37.27523,
# ...

# %%
f = []
z = []
for i in e['통계 거점']:
    if i == '경기':
        z.append('경기')
        f.append([37.275230,127.009477])
    elif i == '전북':
        z.append('전북')
        f.append([35.821859,127.108598])
    elif i == '서울':
        z.append('서울')
        f.append([37.567996,126.978166])
    elif i == '경북':
        z.append('경북')
        f.append([36.575889,128.505793])
    elif i == '인천':
        z.append('인천')
        f.append([37.456390,126.705971])
    elif i == '강원':
        z.append('강원')
        f.append([37.885523,127.729760])
    elif i == '전남':
        z.append('전남')
        f.append([34.816295,126.462874])
    elif i == '충북':
        z.append('충북')
        f.append([36.636007,127.491345])
    elif i == '충남':
        z.append('충남')
        f.append([36.659435,126.672866])
    elif i == '대구':
        z.append('대구')
        f.append([35.871613,128.601836])
    elif i == '울산':
        z.append('울산')
        f.append([35.539171,129.311425])
    elif i == '부산':
        z.append('부산')
        f.append([35.179872,129.074988])
    elif i == '경남':
        z.append('경남')
        f.append([35.238168,128.692397])
    elif i == '광주':
        z.append('광주')
        f.append([35.159823,126.850831])
    elif i == '대전':
        z.append('대전')
        f.append([36.350491,127.384593])
    elif i == '제주':
        z.append('제주')
        f.append([33.499677,126.531247])
    elif i == '세종':
        z.append('세종')
        f.append([36.480263,127.288977])
    else:
        z.append('서울')
        f.append([37.567996,126.978166])

#중앙을 잘모르기때문에 서울의 위경도를 사용

# %%
len(e)

# %%
g = pd.Series(g)
f = pd.Series(f)
z = pd.Series(z)
h = pd.concat([g,f,z], axis = 1)

# %%
print(len(e))
print(len(h))

# %%
h.columns = ["위도", "경도", "통계 거점"]

# %%
e = e.drop(['위도','경도'],axis = 1)

# %%
index = e.index

# %%
index = pd.Series(index)
h = pd.concat([h,index], axis = 1,ignore_index = True)

# %%
h = h.set_index(3)
h
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-166-f1fa262a731c> in <module>
# ----> 1 h = h.set_index(3)
#       2 h
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: 'None of [3] are in the columns'

# %%
df1 = e
df2 = h

# %%
df2 = df2.reset_index()

# %%
df1 = df1.reset_index()

# %%
a = pd.concat([df1,df2], axis = 1)
a
# Out:
#       index  재신고 이전 사건 통계 거점      3           0          1   2
# 0        21          1    강원     21  127.729760  37.885523  강원
# 1        31          1    강원     31  127.729760  37.885523  강원
# 2        38          1    경남     38  128.692397  35.238168  경남
# 3        44          1    경북     44  128.505793  36.575889  경북
# 4        45          1    제주     45  126.531247  33.499677  제주
# 5        46          1    전북     46  127.108598  35.821859  전북
# 6        54          1    강원     54  127.729760  37.885523  강원
# 7        57          1    전북     57  127.108598  35.821859  전북
# 8        66          1    경기     66  127.009477  37.275230  경기
# 9        97          1    경북     97  128.505793  36.575889  경북
# 10      105          1    전북    105  127.108598  35.821859  전북
# 11      113          1    경북    113  128.505793  36.575889  경북
# 12      135          1    부산    135  129.074988  35.179872  부산
# 13      136          1    부산    136  129.074988  35.179872  부산
# ...

# %%
a.columns
# Out:
# Index(['index', '재신고 이전 사건', '통계 거점', 3, 0, 1, 2], dtype='object')

# %%
df = a.drop(['index',3,2], axis = 1)

# %%
df.columns = ['재신고 이전 사건','통계 거점',"위도", "경도"]

# %%
df['위도'] = df['위도'].astype('str')
df['경도'] = df['경도'].astype('str')

# %%
df['SUM'] = df[['위도','경도']].apply(lambda x:','.join(x), axis = 1)

# %%
import folium
map_osm = folium.Map(location =[36, 127], titles = 'Easy', zoom_start = 7)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# for n in df.index:
#     folium.Marker([df['위도'][n], df['경도'][n]], popup = df['통계 거점'][n]).add_to(map_osm)
# map_osm

# %%
m = folium.Map(
    location = [36,127], zoom_start = 8, titles = 'Easy')

# %%
for i in range(len(f)):
    folium.Circle(
        location = f[i],
        radius = 50,
        color =x '#000000',
        fill = 'crimson',
    ).add_to(m)
m.save('map.html')
# Out:
#   File "<ipython-input-179-f534cd1b662e>", line 5
#     color =x '#000000',
#                      ^
# SyntaxError: invalid syntax

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from collections import Counter
a = Counter(df['통계 거점'])
print(a)
# Out:
# Counter({'경기': 850, '전북': 434, '서울': 388, '경북': 317, '강원': 243, '인천': 215, '전남': 207, '충북': 193, '충남': 169, '대구': 151, '울산': 110, '부산': 103, '경남': 101, '광주': 84, '대전': 83, '제주': 79, '세종': 4, '중앙': 4})

# %%
s = pd.Series(a)
s = s.reset_index()

# %%
s = s.drop(['level_0'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-183-531f3abfe9ce> in <module>
# ----> 1 s = s.drop(['level_0'], axis = 1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
s['index']
# Out:
# 0     강원
# 1     경남
# 2     경북
# 3     제주
# 4     전북
# 5     경기
# 6     부산
# 7     서울
# 8     충북
# 9     인천
# 10    대구
# 11    충남
# 12    광주
# 13    대전
# 14    울산
# 15    전남
# 16    세종
# 17    중앙
# Name: index, dtype: object

# %%
for i in s['index']:
    if i == '경기':
        s['위도'] = 37.275230
        s['경도'] = 127.009477
    elif i == '전북':
        s['위도'] = 35.821859
        s['경도'] = 127.108598
    elif i == '서울':
        s['위도'] = 37.567996
        s['경도'] = 126.978166
    elif i == '경북':
        s['위도'] = 36.575889
        s['경도'] = 128.505793
    elif i == '인천':
        s['위도'] = 37.456390
        s['경도'] = 126.705971
    elif i == '강원':
        s['위도'] = 37.885523
        s['경도'] = 127.729760
    elif i == '전남':
        s['위도'] = 34.816295
        s['경도'] = 126.462874
    elif i == '충북':
        s['위도'] = 36.636007
        s['경도'] = 127.491345
    elif i == '충남':
        s['위도'] = 36.659435
        s['경도'] = 126.672866
    elif i == '대구':
        s['위도'] = 35.871613
        s['경도'] = 128.601836
    elif i == '울산':
        s['위도'] = 35.539171
        s['경도'] = 129.31142
    elif i == '부산':
        s['위도'] = 35.179872
        s['경도'] = 129.074988
    elif i == '경남':
        s['위도'] = 35.238168
        s['경도'] = 128.692397
    elif i == '광주':
        s['위도'] = 35.159823
        s['경도'] = 126.850831
    elif i == '대전':
        s['위도'] = 36.350491
        s['경도'] = 127.384593
    elif i == '제주':
        s['위도'] = 33.499677
        s['경도'] = 126.531247
    elif i == '세종':
        s['위도'] = 36.480263
        s['경도'] = 127.288977
    else:
        s['위도'] = 37.567996
        s['경도'] = 126.978166

# %%
s = s.drop(['위도','경도'],axis = 1)

# %%
s
# Out:
#    index    0
# 0     강원  243
# 1     경남  101
# 2     경북  317
# 3     제주   79
# 4     전북  434
# 5     경기  850
# 6     부산  103
# 7     서울  388
# 8     충북  193
# 9     인천  215
# 10    대구  151
# 11    충남  169
# 12    광주   84
# 13    대전   83
# 14    울산  110
# 15    전남  207
# 16    세종    4
# 17    중앙    4

# %%
f = [37.885523,35.238168,36.575889,33.499677,35.821859,37.275230,35.179872,37.567996,36.636007,37.456390,35.871613,36.659435,35.159823,36.350491,35.539171,34.816295,36.480263,37.567996]
g = [127.729760,128.692397,128.505793,126.531247,127.108598,127.009477,129.074988,126.978166,127.491345,126.705971,128.601836,126.672866,126.850831,127.384593,129.31142,126.462874,127.288977,126.978166]

# %%
f = pd.Series(f)
g = pd.Series(g)

# %%
f = f.reset_index()
g = g.reset_index()

# %%
df = pd.concat([s,f,g], axis = 1)

# %%
df
# Out:
#     index    0  index          0  index           0
# 0      강원  243      0  37.885523      0  127.729760
# 1      경남  101      1  35.238168      1  128.692397
# 2      경북  317      2  36.575889      2  128.505793
# 3      제주   79      3  33.499677      3  126.531247
# 4      전북  434      4  35.821859      4  127.108598
# 5      경기  850      5  37.275230      5  127.009477
# 6      부산  103      6  35.179872      6  129.074988
# 7      서울  388      7  37.567996      7  126.978166
# 8      충북  193      8  36.636007      8  127.491345
# 9      인천  215      9  37.456390      9  126.705971
# 10     대구  151     10  35.871613     10  128.601836
# 11     충남  169     11  36.659435     11  126.672866
# 12     광주   84     12  35.159823     12  126.850831
# 13     대전   83     13  36.350491     13  127.384593
# 14     울산  110     14  35.539171     14  129.311420
# 15     전남  207     15  34.816295     15  126.462874
# 16     세종    4     16  36.480263     16  127.288977
# ...

# %%
df.columns = ['지역','횟수',"인덱스1", "위도",'인덱스2','경도']
df
# Out:
#     지역   횟수  인덱스1         위도  인덱스2          경도
# 0   강원  243     0  37.885523     0  127.729760
# 1   경남  101     1  35.238168     1  128.692397
# 2   경북  317     2  36.575889     2  128.505793
# 3   제주   79     3  33.499677     3  126.531247
# 4   전북  434     4  35.821859     4  127.108598
# 5   경기  850     5  37.275230     5  127.009477
# 6   부산  103     6  35.179872     6  129.074988
# 7   서울  388     7  37.567996     7  126.978166
# 8   충북  193     8  36.636007     8  127.491345
# 9   인천  215     9  37.456390     9  126.705971
# 10  대구  151    10  35.871613    10  128.601836
# 11  충남  169    11  36.659435    11  126.672866
# 12  광주   84    12  35.159823    12  126.850831
# 13  대전   83    13  36.350491    13  127.384593
# 14  울산  110    14  35.539171    14  129.311420
# 15  전남  207    15  34.816295    15  126.462874
# 16  세종    4    16  36.480263    16  127.288977
# 17  중앙    4    17  37.567996    17  126.978166

# %%
df = df.drop(['인덱스1', '인덱스2'],axis = 1)
df
# Out:
#     지역   횟수         위도          경도
# 0   강원  243  37.885523  127.729760
# 1   경남  101  35.238168  128.692397
# 2   경북  317  36.575889  128.505793
# 3   제주   79  33.499677  126.531247
# 4   전북  434  35.821859  127.108598
# 5   경기  850  37.275230  127.009477
# 6   부산  103  35.179872  129.074988
# 7   서울  388  37.567996  126.978166
# 8   충북  193  36.636007  127.491345
# 9   인천  215  37.456390  126.705971
# 10  대구  151  35.871613  128.601836
# 11  충남  169  36.659435  126.672866
# 12  광주   84  35.159823  126.850831
# 13  대전   83  36.350491  127.384593
# 14  울산  110  35.539171  129.311420
# 15  전남  207  34.816295  126.462874
# 16  세종    4  36.480263  127.288977
# 17  중앙    4  37.567996  126.978166

# %%
df['지역'].sort_values
# Out:
# <bound method Series.sort_values of 0     강원
# 1     경남
# 2     경북
# 3     제주
# 4     전북
# 5     경기
# 6     부산
# 7     서울
# 8     충북
# 9     인천
# 10    대구
# 11    충남
# 12    광주
# 13    대전
# 14    울산
# 15    전남
# 16    세종
# 17    중앙
# Name: 지역, dtype: object>

# %%
sns.barplot(x = df['지역'], y = df['횟수'])

# %%
df['위도'] = df.위도.astype(float)
df['경도'] = df.경도.astype(float)
df['횟수'] = df.횟수.astype(float)

# %%
map_center = folium.Map(
    location = [36,127], zoom_start = 7, titles = 'Easy')

# %%
for item in df.index:
    latitute = df.loc[item,'경도']
    longtitude = df.loc[item,'위도']
    
    folium.CircleMarker([longtitude,latitute], 
                        radius = df.loc[item,'횟수']/20,
                        popup = df.loc[item,'지역'],
                        color = 'red',
                        fill = True).add_to(map_center)
    
map_center.save('easy.html')
map_center
#한글이 깨지는 이유는 주피터로 켜서 그런거
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
